# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import warnings 
warnings.filterwarnings('ignore')
import folium
from folium.plugins import HeatMap

# %%
# Load the dataset with the correct encoding
data = pd.read_csv('Datasets\\Chicago_Crimes.csv', encoding='ISO-8859-1')

# %%
data.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %%
#FILTERING THE DATAS

#1. DONE ( PRIM_TYPE & Local_Dis [VACANT LOT / LAND])
theft = data[data['Primary Type'] == 'THEFT']

#2. DONE ( PRIM_TYPE & Local_Dis [BANK] )
battery = data[data['Primary Type'] == 'BATTERY'] 

#3. ( PRIM_TYPE & Local_Dis [BANK] )
crim_dam = data[data['Primary Type'] == 'CRIMINAL DAMAGE'] 

#4. ( PRIM_TYPE & Local_Dis [BANK] )
assault= data[data['Primary Type'] == 'ASSAULT'] 

#5. ( PRIM_TYPE & Local_Dis [BANK] )
mo_ve_the = data[data['Primary Type'] == 'MOTOR VEHICLE THEFT'] 

#6. ( PRIM_TYPE & Local_Dis [BANK] )
oth_ffense = data[data['Primary Type'] == 'OTHER OFFENSE'] 

#7. ( PRIM_TYPE & Local_Dis [BANK] )
dece_prac = data[data['Primary Type'] == 'DECEPTIVE PRACTICE'] 

#8. ( PRIM_TYPE & Local_Dis [BANK] )
burglary = data[data['Primary Type'] == 'BURGLARY'] 

#9. ( PRIM_TYPE & Local_Dis [BANK] )
robbery = data[data['Primary Type'] == 'ROBBERY'] 

#10. ( PRIM_TYPE & Local_Dis [BANK] )
wea_vio = data[data['Primary Type'] == 'WEAPONS VIOLATION'] 

#11. ( PRIM_TYPE & Local_Dis [BANK] )
narcotics = data[data['Primary Type'] == 'NARCOTICS'] 

#12. ( PRIM_TYPE & Local_Dis [BANK] )
crim_tres = data[data['Primary Type'] == 'CRIMINAL TRESPASS'] 

#13. ( PRIM_TYPE & Local_Dis [BANK] )
off_inv_chil = data[data['Primary Type'] == 'OFFENSE INVOLVING CHILDREN'] 

#14( PRIM_TYPE & Local_Dis [BANK] )
crim_sex_ass = data[data['Primary Type'] == 'CRIMINAL SEXUAL ASSAULT'] 

#15. ( PRIM_TYPE & Local_Dis [BANK] )
sex_off = data[data['Primary Type'] == 'SEX OFFENSE'] 

#16. ( PRIM_TYPE & Local_Dis [BANK] )
pub_pea_vio = data[data['Primary Type'] == 'PUBLIC PEACE VIOLATION'] 

#17. ( PRIM_TYPE & Local_Dis [BANK] )
inter_wi_po = data[data['Primary Type'] == 'INTERFERENCE WITH PUBLIC OFFICER'] 

#18. ( PRIM_TYPE & Local_Dis [BANK] )
homicide = data[data['Primary Type'] == 'HOMICIDE'] 

#19. ( PRIM_TYPE & Local_Dis [BANK] )
stalking = data[data['Primary Type'] == 'STALKING'] 

#20. ( PRIM_TYPE & Local_Dis [BANK] )
arson = data[data['Primary Type'] == 'ARSON'] 

#21. ( PRIM_TYPE & Local_Dis [BANK] )
prosti = data[data['Primary Type'] == 'PROSTITUTION'] 

#22. ( PRIM_TYPE & Local_Dis [BANK] )
con_car_lilation = data[data['Primary Type'] == 'CONCEALED CARRY LICENSE VIOLATION'] 

#23. ( PRIM_TYPE & Local_Dis [BANK] )
liq_law_lation = data[data['Primary Type'] == 'LIQUOR LAW VIOLATION'] 

#24. ( PRIM_TYPE & Local_Dis [BANK] )
intimidation = data[data['Primary Type'] == 'INTIMIDATION'] 

#25. ( PRIM_TYPE & Local_Dis [BANK] )
kidnapping = data[data['Primary Type'] == 'KIDNAPPING'] 

#26. ( PRIM_TYPE & Local_Dis [BANK] )
obscenity = data[data['Primary Type'] == 'OBSCENITY'] 

#27. ( PRIM_TYPE & Local_Dis [BANK] )
human_traff = data[data['Primary Type'] == 'HUMAN TRAFFICKING'] 

#28. ( PRIM_TYPE & Local_Dis [BANK] )
gambling = data[data['Primary Type'] == 'GAMBLING'] 

#29. ( PRIM_TYPE & Local_Dis [BANK] )
public_inden = data[data['Primary Type'] == 'PUBLIC INDECENCY'] 

#30.( PRIM_TYPE & Local_Dis [BANK] )
oth_nar_lation = data[data['Primary Type'] == 'OTHER NARCOTIC VIOLATION'] 

#31( PRIM_TYPE & Local_Dis [BANK] )
non_crim = data[data['Primary Type'] == 'NON-CRIMINAL']

# %% [markdown]
# <h1>1. THEFT ANALYSIS</h1>

# %%
#FILTERING THEFT

theft_2 = theft[theft['Location Description'] == 'VACANT LOT / LAND']
#theft_3 = theft_2[theft_2['Ward'] == 1]

#DATA AGGREGATION
final_filter_1 = theft_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'theft_count')
final_filter_1

#Converting Pandas Data Frame into Python List
final_filter_1["normalize_data"] = final_filter_1['theft_count'] - final_filter_1['theft_count'].min() / final_filter_1['theft_count'].max() - final_filter_1['theft_count']

heatmap_data = final_filter_1[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
theft_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(theft_map)

# Show
theft_map

# %% [markdown]
# <h1>2. BATTERY ANALYSIS</h1>

# %%
#FILTERING BATTERY

battery_2 = battery[battery['Location Description'] == 'BANK']
#battery_3 = battery_2[battery_2['Ward'] == 2 ]

#DATA AGGREGATION
final_filter_2 = battery_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'battery_count')
final_filter_2

#Converting Pandas Data Frame into Python List
final_filter_2["normalize_data"] = final_filter_2['battery_count'] - final_filter_2['battery_count'].min() / final_filter_2['battery_count'].max() - final_filter_2['battery_count']

heatmap_data = final_filter_2[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
battery_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(battery_map)
battery_map.save('battery_map.html')

#Show
battery_map

# %% [markdown]
# <H1>3. CRIMINAL DAMAGE</H1>

# %%
#FILTERING CRIMINAL

crim_dam_2 = crim_dam[crim_dam['Location Description'] == 'CTA PLATFORM']
#crim_dam_3 = crim_dam_2[battery_2['Ward'] == 2 ]

#DATA AGGREGATION
final_filter_3 = crim_dam_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'crimedamage_count')
final_filter_3

#Converting Pandas Data Frame into Python List
final_filter_3["normalize_data"] = final_filter_3['crimedamage_count'] - final_filter_3['crimedamage_count'].min() / final_filter_3['crimedamage_count'].max() - final_filter_3['crimedamage_count']

heatmap_data = final_filter_3[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
crimedamage_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(crimedamage_map)

#Show
crimedamage_map

# %% [markdown]
# <h1>4. ASSAULT ANALYSIS</h1>

# %%
#FILTERING THEFT

assault_2 = assault[assault['Location Description'] == 'DRIVEWAY - RESIDENTIAL']
#theft_3 = theft_2[theft_2['Ward'] == 1]

#DATA AGGREGATION
final_filter_4 = assault_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'assault_count')

#Converting Pandas Data Frame into Python List
final_filter_4["normalize_data"] = final_filter_4['assault_count'] - final_filter_4['assault_count'].min() / final_filter_4['assault_count'].max() - final_filter_4['assault_count']

heatmap_data = final_filter_4[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
assault_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(assault_map)

#Show
assault_map

# %% [markdown]
# <h1>5. MOTOR VEHICLE THEFT</h1>

# %%
#FILTERING MOTOR THEFT 

mo_ve_the_2 = mo_ve_the[mo_ve_the['Location Description'] == 'CTA BUS']
#mo_ve_the_3 = mo_ve_the_2[mo_ve_the_2['Ward'] == 23 ]

#DATA AGGREGATION
final_filter_5 = mo_ve_the_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'motortheft_count')
final_filter_5

#Converting Pandas Data Frame into Python List
final_filter_5["normalize_data"] = final_filter_5['motortheft_count'] - final_filter_5['motortheft_count'].min() / final_filter_5['motortheft_count'].max() - final_filter_5['motortheft_count']

heatmap_data = final_filter_5[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
motortheft_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(motortheft_map)

#Show
motortheft_map

# %% [markdown]
# <H1>6. OTHER OFFENSE</H1>

# %%
#FILTERING MOTOR THEFT 

oth_ffense_2 = oth_ffense[oth_ffense['Location Description'] == 'HOTEL / MOTEL']
#oth_ffense_3 = oth_ffense_2[oth_ffense_2['Ward'] == 3 ]

#DATA AGGREGATION
final_filter_6 = oth_ffense_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'otheroffense_count')
final_filter_6

#Converting Pandas Data Frame into Python List
final_filter_6["normalize_data"] = final_filter_6['otheroffense_count'] - final_filter_6['otheroffense_count'].min() / final_filter_6['otheroffense_count'].max() - final_filter_6['otheroffense_count']

heatmap_data = final_filter_6[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
otheroffense_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(otheroffense_map)

#Show
# otheroffense_map

# %% [markdown]
# <H1>7. DECEPTIVE PRACTICE</H1>

# %%
#FILTERING DECEPTIVE PRACTICE

dece_prac_2 = dece_prac[dece_prac['Location Description'] == 'SCHOOL - PUBLIC BUILDING']
#oth_ffense_3 = oth_ffense_2[oth_ffense_2['Ward'] == 3 ]

#DATA AGGREGATION
final_filter_7 = dece_prac_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'otheroffense_count')
final_filter_7

#Converting Pandas Data Frame into Python List
final_filter_7["normalize_data"] = final_filter_7['otheroffense_count'] - final_filter_7['otheroffense_count'].min() / final_filter_7['otheroffense_count'].max() - final_filter_7['otheroffense_count']

heatmap_data = final_filter_7[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
deceptive_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(deceptive_map)

#Show
deceptive_map

# %% [markdown]
# <H1>8. BURGALRY ANALYSIS </H1>

# %%
#FILTERING DECEPTIVE PRACTICE

burglary_2 = burglary[burglary['Location Description'] == 'HOSPITAL BUILDING / GROUNDS']
#oth_ffense_3 = oth_ffense_2[oth_ffense_2['Ward'] == 3 ]

#DATA AGGREGATION
final_filter_8 = burglary_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'burglary_count')

#Converting Pandas Data Frame into Python List
final_filter_8["normalize_data"] = final_filter_8['burglary_count'] - final_filter_8['burglary_count'].min() / final_filter_8['burglary_count'].max() - final_filter_8['burglary_count']

heatmap_data = final_filter_8[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
burglary_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(burglary_map)

#Show
burglary_map

# %% [markdown]
# <H1>9. ROBBERY ANALYSIS</H1>

# %%
#FILTERING ROBBERY

robbery_2 = robbery[robbery['Location Description'] == 'SCHOOL - PUBLIC GROUNDS']
#oth_ffense_3 = oth_ffense_2[oth_ffense_2['Ward'] == 3 ]

#DATA AGGREGATION
final_filter_9 = robbery_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'robbery_count')

#Converting Pandas Data Frame into Python List
final_filter_9["normalize_data"] = final_filter_9['robbery_count'] - final_filter_9['robbery_count'].min() / final_filter_9['robbery_count'].max() - final_filter_9['robbery_count']

heatmap_data = final_filter_9[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
robbery_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(robbery_map)

#Show
robbery_map

# %% [markdown]
# <h1>10. WEAPON VIOLATIONS ANALYSIS</h1>

# %%
#FILTERING ROBBERY

wea_vio_2 = wea_vio[wea_vio['Location Description'] == 'CTA TRAIN']
#oth_ffense_3 = oth_ffense_2[oth_ffense_2['Ward'] == 3 ]

#DATA AGGREGATION
final_filter_10 = wea_vio_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'weaponsviolation_count')

#Converting Pandas Data Frame into Python List
final_filter_10["normalize_data"] = final_filter_10['weaponsviolation_count'] - final_filter_10['weaponsviolation_count'].min() / final_filter_10['weaponsviolation_count'].max() - final_filter_10['weaponsviolation_count']

heatmap_data = final_filter_10[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
weaponsviolation_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(weaponsviolation_map)

#Show
weaponsviolation_map

# %% [markdown]
# <H1>11. NARCOTICS ANALYSIS</H1>

# %%
#FILTERING NARCOTICS

narcotics_2 = narcotics[narcotics['Location Description'] == 'BAR OR TAVERN']
#oth_ffense_3 = oth_ffense_2[oth_ffense_2['Ward'] == 3 ]

#DATA AGGREGATION
final_filter_11 = narcotics_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'narcotics_count')

#Converting Pandas Data Frame into Python List
final_filter_11["normalize_data"] = final_filter_11['narcotics_count'] - final_filter_11['narcotics_count'].min() / final_filter_11['narcotics_count'].max() - final_filter_11['narcotics_count']

heatmap_data = final_filter_11[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
narcotics_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(narcotics_map)

#Show
narcotics_map

# %% [markdown]
# <H1>12. CRIMINAL TRESPASS ANALYSIS</H1>

# %%
#FILTERING CRIMINAL TRESPASS

crim_tres_2 = crim_tres[crim_tres['Location Description'] == 'DRUG STORE']
#oth_ffense_3 = oth_ffense_2[oth_ffense_2['Ward'] == 3 ]

#DATA AGGREGATION
final_filter_12 = crim_tres_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'crimtres_count')

#Converting Pandas Data Frame into Python List
final_filter_12["normalize_data"] = final_filter_12['crimtres_count'] - final_filter_12['crimtres_count'].min() / final_filter_12['crimtres_count'].max() - final_filter_12['crimtres_count']

heatmap_data = final_filter_12[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
crimtres_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(crimtres_map)

#Show
crimtres_map

# %% [markdown]
# <H1>13. OFFENSE INVOLVING CHILDREN ANALYSIS</H1>

# %%
#FILTERING OFFENSE INVOLVING CHILDREN

off_inv_chil_2 = off_inv_chil[off_inv_chil['Location Description'] == 'PARK PROPERTY']
#oth_ffense_3 = oth_ffense_2[oth_ffense_2['Ward'] == 3 ]

#DATA AGGREGATION
final_filter_13 = off_inv_chil_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'off_count')

#Converting Pandas Data Frame into Python List
final_filter_13["normalize_data"] = final_filter_13['off_count'] - final_filter_13['off_count'].min() / final_filter_13['off_count'].max() - final_filter_13['off_count']

heatmap_data = final_filter_13[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
off_inv_chil_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(off_inv_chil_map)

#Show
off_inv_chil_map

# %% [markdown]
# <H1>14. CRIMINAL SEXUAL ASSAULT ANALYSIS</H1>

# %%
#FILTERING CRIMINAL SEXUAL ASSAULT

crim_sex_ass_2 = crim_sex_ass[crim_sex_ass['Location Description'] == 'CONVENIENCE STORE']
#oth_ffense_3 = oth_ffense_2[oth_ffense_2['Ward'] == 3 ]

#DATA AGGREGATION
final_filter_14 = crim_sex_ass_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'crim_sex_count')

#Converting Pandas Data Frame into Python List
final_filter_14["normalize_data"] = final_filter_14['crim_sex_count'] - final_filter_14['crim_sex_count'].min() / final_filter_14['crim_sex_count'].max() - final_filter_14['crim_sex_count']

heatmap_data = final_filter_14[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
crimsex_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(crimsex_map)

#Show
crimsex_map

# %% [markdown]
# <H1>15. SEX OFFENSE ANALYSIS</H1>

# %%
#FILTERING SEDX OFFENSE

sex_off_2 = sex_off[sex_off['Location Description'] == 'RESIDENCE - GARAGE']
#oth_ffense_3 = oth_ffense_2[oth_ffense_2['Ward'] == 3 ]

#DATA AGGREGATION
final_filter_15 = sex_off_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'sexoff_count')

#Converting Pandas Data Frame into Python List
final_filter_15["normalize_data"] = final_filter_15['sexoff_count'] - final_filter_15['sexoff_count'].min() / final_filter_15['sexoff_count'].max() - final_filter_15['sexoff_count']

heatmap_data = final_filter_15[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
sexoff_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(sexoff_map)

#Show
sexoff_map

# %% [markdown]
# <H1>16. PUBLIC PEACE VIOLATION ANALYSIS</H1>

# %%
#FILTERING PUBLIC PEACE VIOLATION

pub_pea_vio_2 = pub_pea_vio[pub_pea_vio['Location Description'] == 'RESIDENCE - YARD (FRONT / BACK)']
#oth_ffense_3 = oth_ffense_2[oth_ffense_2['Ward'] == 3 ]

#DATA AGGREGATION
final_filter_16 = pub_pea_vio_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'public_count')

#Converting Pandas Data Frame into Python List
final_filter_16["normalize_data"] = final_filter_16['public_count'] - final_filter_16['public_count'].min() / final_filter_16['public_count'].max() - final_filter_16['public_count']

heatmap_data = final_filter_16[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
publicoff_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(publicoff_map)

#Show
publicoff_map

# %% [markdown]
# <H1>17. INTERFERENCE WITH PUBLIC OFFICER ANALYSIS</H1>

# %%
#FILTERING INTERFERENCE WITH PUBLIC OFFICER

inter_wi_po_2 = inter_wi_po[inter_wi_po['Ward'] == 3]

#DATA AGGREGATION
final_filter_17 = inter_wi_po_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'inter_count')

#Converting Pandas Data Frame into Python List
final_filter_17["normalize_data"] = final_filter_17['inter_count'] - final_filter_17['inter_count'].min() / final_filter_17['inter_count'].max() - final_filter_17['inter_count']

heatmap_data = final_filter_17[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
interference_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(interference_map)

#Show
interference_map

# %% [markdown]
# <H1>18. HOMICIDE ANALYSIS</H1>

# %%
#FILTERING HOMICIDE

homicide_2 = homicide[homicide['Ward'] == 20]

#DATA AGGREGATION
final_filter_18 = homicide_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'homi_count')

#Converting Pandas Data Frame into Python List
final_filter_18["normalize_data"] = final_filter_18['homi_count'] - final_filter_18['homi_count'].min() / final_filter_18['homi_count'].max() - final_filter_18['homi_count']

heatmap_data = final_filter_18[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
homi_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(homi_map)

#Show
homi_map

# %% [markdown]
# <H1>19. STALKING ANALYSIS</H1>

# %%
#FILTERING STALKING

stalking_2 = stalking[stalking['Ward'] == 15]

#DATA AGGREGATION
final_filter_19 = stalking_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'stalking_count')

#Converting Pandas Data Frame into Python List
final_filter_19["normalize_data"] = final_filter_19['stalking_count'] - final_filter_19['stalking_count'].min() / final_filter_19['stalking_count'].max() - final_filter_19['stalking_count']

heatmap_data = final_filter_19[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
stalking_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(stalking_map)

#Show
stalking_map

# %% [markdown]
# <H1>20. ARSON ANALYSIS</H1>

# %%
#FILTERING ARSON

arson_2 = arson[arson['Ward'] == 10]

#DATA AGGREGATION
final_filter_20 = arson_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'arson_count')

#Converting Pandas Data Frame into Python List
final_filter_20["normalize_data"] = final_filter_20['arson_count'] - final_filter_20['arson_count'].min() / final_filter_20['arson_count'].max() - final_filter_20['arson_count']

heatmap_data = final_filter_20[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
arson_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(arson_map)

#Show
arson_map

# %% [markdown]
# <H1>21. PROSTITUTION </H1>

# %%
#FILTERING PROSTITUTION

prosti_2 = prosti[prosti['Location Description'] == 'SIDEWALK']

#DATA AGGREGATION
final_filter_21 = prosti_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'prosti_count')

#Converting Pandas Data Frame into Python List
final_filter_21["normalize_data"] = final_filter_21['prosti_count'] - final_filter_21['prosti_count'].min() / final_filter_21['prosti_count'].max() - final_filter_21['prosti_count']

heatmap_data = final_filter_21[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
prosti_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(prosti_map)

#Show
prosti_map

# %% [markdown]
# <H1>22. CONCEALED CARRY LICENSE VIOLATION ANALYSIS</H1>

# %%
#FILTERING CONCEALED CARRY LICENSE VIOLATION

con_car_lilation_2 = con_car_lilation[con_car_lilation['Location Description'] == 'STREET']

#DATA AGGREGATION
final_filter_22 = con_car_lilation_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'concar_count')

#Converting Pandas Data Frame into Python List
final_filter_22["normalize_data"] = final_filter_22['concar_count'] - final_filter_22['concar_count'].min() / final_filter_22['concar_count'].max() - final_filter_22['concar_count']

heatmap_data = final_filter_22[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
concar_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(concar_map)

#Show
concar_map

# %% [markdown]
# <H1>23. LIQUOR LAW VIOLATION  ANALYSIS</H1>

# %%
#FILTERING LIQUOR LAW VIOLATION 

liq_law_lation_2 = liq_law_lation[liq_law_lation['Location Description'] == 'STREET']

#DATA AGGREGATION
final_filter_23 = liq_law_lation_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'liq_count')

#Converting Pandas Data Frame into Python List
final_filter_23["normalize_data"] = final_filter_23['liq_count'] - final_filter_23['liq_count'].min() / final_filter_23['liq_count'].max() - final_filter_23['liq_count']

heatmap_data = final_filter_23[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
liq_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(liq_map)

#Show
liq_map

# %% [markdown]
# <H1>24. INTIMIDATION ANALYSIS</H1>

# %%
#FILTERING INTIMIDATION

intimidation_2 = intimidation[intimidation['Location Description'] == 'STREET']

#DATA AGGREGATION
final_filter_24 = intimidation_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'INTI_count')

#Converting Pandas Data Frame into Python List
final_filter_24["normalize_data"] = final_filter_24['INTI_count'] - final_filter_24['INTI_count'].min() / final_filter_24['INTI_count'].max() - final_filter_24['INTI_count']

heatmap_data = final_filter_24[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
inti_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(inti_map)

#Show
inti_map

# %% [markdown]
# <H1>25.ARSON ANALYSIS</H1>

# %%
# kidnapping
# #FILTERING NARCOTICS

# kidnapping_2 = kidnapping[kidnapping['Location Description'] == 'APARTMENT']

# #DATA AGGREGATION
# final_filter_25 = kidnapping_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'kid_count')

# #Converting Pandas Data Frame into Python List
# final_filter_25["normalize_data"] = final_filter_25['kid_count'] - final_filter_25['kid_count'].min() / final_filter_25['kid_count'].max() - final_filter_25['kid_count']

# heatmap_data = final_filter_25[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

# #Creating a base map
# kid_map = folium.Map(location = [30, 40], zoom_start = 3)

# #Adding HeatMap
# HeatMap(heatmap_data).add_to(kid_map)

# #Show
# kid_map

# %% [markdown]
# <H1>26. OBSCENITY ANALYSIS</H1>

# %%
#FILTERING OBSCENITY

obscenity_2 = obscenity[obscenity['Location Description'] == 'RESIDENCE']

#DATA AGGREGATION
final_filter_26 = obscenity_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'obs_count')

#Converting Pandas Data Frame into Python List
final_filter_26["normalize_data"] = final_filter_26['obs_count'] - final_filter_26['obs_count'].min() / final_filter_26['obs_count'].max() - final_filter_26['obs_count']

heatmap_data = final_filter_26[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
obs_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(obs_map)

#Show
obs_map

# %% [markdown]
# <H1>27. HUMAN TRAFFICKING ANALYSIS</H1>

# %%
#FILTERING HUMAN TRAFFICKING

human_traff_2 = human_traff[human_traff['Location Description'] == 'STREET']

#DATA AGGREGATION
final_filter_27 = human_traff_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'hums_count')

#Converting Pandas Data Frame into Python List
final_filter_27["normalize_data"] = final_filter_27['hums_count'] - final_filter_27['hums_count'].min() / final_filter_27['hums_count'].max() - final_filter_27['hums_count']

heatmap_data = final_filter_27[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
hum_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(hum_map)

#Show
hum_map

# %% [markdown]
# <H1>28. GAMBLING ANALYSIS</H1>

# %%
#FILTERING GAMBLING

gambling_2 = gambling[gambling['Location Description'] == 'SIDEWALK']

#DATA AGGREGATION
final_filter_28 = gambling_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'gam_count')

#Converting Pandas Data Frame into Python List
final_filter_28["normalize_data"] = final_filter_28['gam_count'] - final_filter_28['gam_count'].min() / final_filter_28['gam_count'].max() - final_filter_28['gam_count']

heatmap_data = final_filter_28[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
gam_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(gam_map)

#Show
gam_map

# %% [markdown]
# <H1>29. PUBLIC INDECENCY ANALYSIS</H1>

# %%
#FILTERING VPUBLIC INDECENCY

public_inden_2 = public_inden.loc[public_inden['Location Description']== 'STREET']

#DATA AGGREGATION
final_filter_29 = public_inden_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'public_count')

#Converting Pandas Data Frame into Python List
final_filter_29["normalize_data"] = final_filter_29['public_count'] - final_filter_29['public_count'].min() / final_filter_29['public_count'].max() - final_filter_29['public_count']

heatmap_data = final_filter_29[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
public_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(public_map)

#Show
public_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <H1>30. OTHER NARCOTIC VIOLATION ANALYSIS</H1>

# %%
#FILTERING OTHER NARCOTIC VIOLATION

oth_nar_lation_2 = oth_nar_lation[oth_nar_lation['Location Description']== 'STREET']

#DATA AGGREGATION
final_filter_3O = oth_nar_lation_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'OTH_count')

#Converting Pandas Data Frame into Python List
final_filter_3O["normalize_data"] = final_filter_3O['OTH_count'] - final_filter_3O['OTH_count'].min() / final_filter_3O['OTH_count'].max() - final_filter_3O['OTH_count']

heatmap_data = final_filter_3O[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
OTH_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(OTH_map)

#Show
OTH_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <H1>31. NON-CRIMINAL ANALYSIS</H1>

# %%
#FILTERING NON-CRIMINAL

non_crim_2 = non_crim[non_crim['Location Description']== 'STREET']

#DATA AGGREGATION
final_filter_31 = non_crim_2.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'NONCRIM_count')

#Converting Pandas Data Frame into Python List
final_filter_31["normalize_data"] = final_filter_31['NONCRIM_count'] - final_filter_31['NONCRIM_count'].min() / final_filter_31['NONCRIM_count'].max() - final_filter_31['NONCRIM_count']

heatmap_data = final_filter_31[['Latitude', 'Longitude', 'normalize_data']].values.tolist()

#Creating a base map
NONCRIM_map = folium.Map(location = [30, 40], zoom_start = 3)

#Adding HeatMap
HeatMap(heatmap_data).add_to(NONCRIM_map)

#Show
NONCRIM_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Out:
# Primary Type
# THEFT                                59201
# BATTERY                              44579
# CRIMINAL DAMAGE                      27094
# ASSAULT                              22615
# MOTOR VEHICLE THEFT                  19604
# OTHER OFFENSE                        16781
# DECEPTIVE PRACTICE                   14991
# BURGLARY                              8443
# ROBBERY                               8200
# WEAPONS VIOLATION                     7164
# NARCOTICS                             6627
# CRIMINAL TRESPASS                     5045
# OFFENSE INVOLVING CHILDREN            1597
# CRIMINAL SEXUAL ASSAULT               1573
# SEX OFFENSE                           1210
# PUBLIC PEACE VIOLATION                1006
# INTERFERENCE WITH PUBLIC OFFICER       771
# HOMICIDE                               553
# STALKING                               520
# ARSON                                  452
# PROSTITUTION                           287
# ...

# %%
# Out:
# Location Description
# STREET                                    66040
# APARTMENT                                 47787
# RESIDENCE                                 29776
# SIDEWALK                                  13265
# SMALL RETAIL STORE                         9858
# PARKING LOT / GARAGE (NON RESIDENTIAL)     8350
# RESTAURANT                                 6094
# DEPARTMENT STORE                           5768
# ALLEY                                      5695
# OTHER (SPECIFY)                            4072
# COMMERCIAL / BUSINESS OFFICE               3712
# VEHICLE NON-COMMERCIAL                     3667
# GAS STATION                                2993
# RESIDENCE - PORCH / HALLWAY                2988
# GROCERY FOOD STORE                         2615
# RESIDENCE - YARD (FRONT / BACK)            2586
# RESIDENCE - GARAGE                         2391
# CONVENIENCE STORE                          1919
# PARK PROPERTY                              1844
# ...
